# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
# read img
img = cv.imread('input/real_bill.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "Image not found"

# find and show edges
edges = cv.Canny(img, 100, 200)

plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Edge Image'), ([], []), ([], []))

# %%
# find min max values of canny edges
pts = np.argwhere(edges > 0)
y1, x1 = pts.min(axis=0)
y2, x2 = pts.max(axis=0)

# %%
# crop img to those points
cropped = img[y1:y2, x1:x2]
cv.imwrite('output/cropped_real_bill.jpg', cropped)

plt.imshow(cropped)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# repeat with better image without children of dune book circles
img = cv.imread('input/real_bill2.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "Image not found"

# find and show edges
edges = cv.Canny(img, 100, 200)

plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Edge Image'), ([], []), ([], []))

# %%
# find min max values of canny edges
pts = np.argwhere(edges > 0)
y1, x1 = pts.min(axis=0)
y2, x2 = pts.max(axis=0)

# crop img to those points
cropped = img[y1:y2, x1:x2]
cv.imwrite('output/cropped_real_bill2.jpg', cropped)

plt.imshow(cropped)
plt.show()
